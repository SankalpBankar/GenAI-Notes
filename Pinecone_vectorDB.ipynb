# %%
# !pip install -U langchain langchain-core langchain-community langchain-text-splitters langchain-groq pinecone-client sentence-transformers pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.2/106.2 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.2/467.2 kB 14.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 51.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.6/323.6 kB 16.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 44.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.4/155.4 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.6/207.6 kB 14.8 MB/s eta 0:00:00
# ...

# %%
from langchain_community.document_loaders import PyPDFDirectoryLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_groq import ChatGroq
from langchain_community.vectorstores import Pinecone
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2995481013.py in <cell line: 0>()
#       4 from langchain_groq import ChatGroq
#       5 from langchain_community.vectorstores import Pinecone
# ----> 6 from langchain.chains.retrieval import create_retrieval_chain
#       7 from langchain.chains.combine_documents import create_stuff_documents_chain
#       8 from langchain.prompts import PromptTemplate
#
# ModuleNotFoundError: No module named 'langchain.chains'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !mkdir pdfs

# %%
# !pip install pypdf

# %%
# !pip install langchain -U langchain_community

# %%
import os
from langchain_community.document_loaders import PyPDFDirectoryLoader

pdf_dir = "pdfs"
loader = PyPDFDirectoryLoader(pdf_dir)
data = loader.load()

if not os.listdir(pdf_dir):
    print(f"The directory '{pdf_dir}' is empty. Please upload PDF files to this directory.")
elif not data:
    print(f"No data was loaded from the PDF files in '{pdf_dir}'. Please check the files for readability.")
else:
    print(f"Successfully loaded {len(data)} documents from '{pdf_dir}'.")
# Out:
# Successfully loaded 15 documents from 'pdfs'.

# %%
if data:
  print(data[0])
else:
  print("The 'data' list is empty. Cannot access element at index 0.")
# Out:
# page_content='Provided proper attribution is provided, Google hereby grants permission to
# reproduce the tables and figures in this paper solely for use in journalistic or
# scholarly works.
# Attention Is All You Need
# Ashish Vaswani∗
# Google Brain
# avaswani@google.com
# Noam Shazeer∗
# Google Brain
# noam@google.com
# Niki Parmar∗
# Google Research
# nikip@google.com
# Jakob Uszkoreit∗
# Google Research
# usz@google.com
# Llion Jones∗
# Google Research
# llion@google.com
# Aidan N. Gomez∗ †
# University of Toronto
# aidan@cs.toronto.edu
# Łukasz Kaiser∗
# Google Brain
# lukaszkaiser@google.com
# Illia Polosukhin∗ ‡
# illia.polosukhin@gmail.com
# Abstract
# The dominant sequence transduction models are based on complex recurrent or
# convolutional neural networks that include an encoder and a decoder. The best
# performing models also connect the encoder and decoder through an attention
# mechanism. We propose a new simple network architecture, the Transformer,
# ...

# %%
text_splitter=RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=20)

# %%
text_chunks=text_splitter.split_documents(data)

# %%
print(text_chunks[0].page_content)
# Out:
# Provided proper attribution is provided, Google hereby grants permission to
# reproduce the tables and figures in this paper solely for use in journalistic or
# scholarly works.
# Attention Is All You Need
# Ashish Vaswani∗
# Google Brain
# avaswani@google.com
# Noam Shazeer∗
# Google Brain
# noam@google.com
# Niki Parmar∗
# Google Research
# nikip@google.com
# Jakob Uszkoreit∗
# Google Research
# usz@google.com
# Llion Jones∗
# Google Research
# llion@google.com
# Aidan N. Gomez∗ †
# University of Toronto
# aidan@cs.toronto.edu

# %%
print(text_chunks[1].page_content)
# Out:
# Łukasz Kaiser∗
# Google Brain
# lukaszkaiser@google.com
# Illia Polosukhin∗ ‡
# illia.polosukhin@gmail.com
# Abstract
# The dominant sequence transduction models are based on complex recurrent or
# convolutional neural networks that include an encoder and a decoder. The best
# performing models also connect the encoder and decoder through an attention
# mechanism. We propose a new simple network architecture, the Transformer,
# based solely on attention mechanisms, dispensing with recurrence and convolutions

# %%
len(text_chunks)
# Out:
# 90

# %%
import os
os.environ["GROQ_API_KEY"]="Paste your API Key"

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_groq import ChatGroq

# Use Hugging Face for embeddings
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Use Groq for LLM
llm = ChatGroq(api_key="Paste your API Key", model_name="llama-3.1-8b-instant")  # example model
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-1710337170.py in <cell line: 0>()
#       1 from langchain_community.embeddings import HuggingFaceEmbeddings
# ----> 2 from langchain_groq import ChatGroq
#       3
#       4 # Use Hugging Face for embeddings
#       5 embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
#
# /usr/local/lib/python3.12/dist-packages/langchain_groq/__init__.py in <module>
#       1 """Groq integration for LangChain."""
#       2
# ----> 3 from langchain_groq.chat_models import ChatGroq
#       4 from langchain_groq.version import __version__
#       5
#
# /usr/local/lib/python3.12/dist-packages/langchain_groq/chat_models.py in <module>
#      58 from typing_extensions import Self
#      59
# ---> 60 from langchain_groq._compat import _convert_from_v1_to_groq
# ...

# %%
embeddings.embed_query("How are you")
# Out:
# [-0.031368959695100784,
#  0.03783048316836357,
#  0.07630816102027893,
#  0.04569956660270691,
#  -0.0012047089403495193,
#  -0.0747690424323082,
#  0.08157840371131897,
#  0.010209391824901104,
#  -0.11220549046993256,
#  0.04073433205485344,
#  -0.044705793261528015,
#  -0.009028689935803413,
#  -0.02297622710466385,
#  -0.009182573296129704,
#  0.007133586797863245,
#  -0.03529726713895798,
#  0.07896506786346436,
#  -0.09915599226951599,
#  -0.12103833258152008,
#  0.03257376700639725,
#  -0.09918763488531113,
#  0.03196955472230911,
#  0.0017395131289958954,
#  0.08815883845090866,
#  -0.026670141145586967,
#  0.01709159091114998,
#  -0.04135069251060486,
#  -0.03918188065290451,
#  0.035009197890758514,
#  -0.07608205825090408,
#  -0.06472423672676086,
#  0.022676268592476845,
#  -0.049569178372621536,
#  -0.027594182640314102,
#  -0.057269640266895294,
#  -0.04053013399243355,
#  0.01654030755162239,
#  -0.10059665143489838,
#  -0.048732414841651917,
# ...

# %%
len(embeddings.embed_query("How are you"))
# Out:
# 384

# %%
import os
from google.colab import userdata

PINECONE_API_KEY = userdata.get('PINECONE_API_KEY')
PINECONE_API_ENV=os.environ.get('PINECONE_API_ENV', 'us-east-1')

# %%
# !pip install pinecone

# %%
import pinecone

# %%
import os
from pinecone import Pinecone, ServerlessSpec
from google.colab import userdata

PINECONE_API_KEY = userdata.get('PINECONE_API_KEY')
PINECONE_API_ENV=os.environ.get('PINECONE_API_ENV', 'us-east-1')

pc = Pinecone(api_key=PINECONE_API_KEY, environment=PINECONE_API_ENV)

# %%
index_name = "llama-text-embed-v2-index" #Put in the name of your pinecone index here

# %%
index=pc.Index('llama-text-embed-v2-index')

# %% [markdown]
# # Create Embeddings for each of the Text Chunk

# %%
from langchain_community.document_loaders import PyPDFDirectoryLoader
pdf_dir = "pdfs"
loader = PyPDFDirectoryLoader(pdf_dir)
data = loader.load()

# %%
import os
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Pinecone
from pinecone import Pinecone as PineconeClient

# %%
os.environ["PINECONE_API_KEY"] = "Paste your Pinecone API Key"

# Initialize Pinecone client
pc = PineconeClient(api_key=os.environ["PINECONE_API_KEY"])

# (Optional) Create index if it doesn’t exist
index_name = "langchain-index"
if index_name not in [idx["name"] for idx in pc.list_indexes()]:
    pc.create_index(
        name=index_name,
        dimension=384,  # must match embedding size
        metric="cosine",
        spec=ServerlessSpec(cloud="aws", region="us-east-1")
    )

# %%
# !pip install -U langchain-huggingface
# Out:
# ...
#   Using cached langchain_core-1.0.0-py3-none-any.whl.metadata (3.4 kB)
# ...
# Using cached langchain_core-1.0.0-py3-none-any.whl (467 kB)
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.79
#     Uninstalling langchain-core-0.3.79:
#       Successfully uninstalled langchain-core-0.3.79
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-openai 0.3.35 requires langchain-core<1.0.0,>=0.3.78, but you have langchain-core 1.0.0 which is incompatible.
# langchain-pinecone 0.2.12 requires langchain-core<1.0.0,>=0.3.34, but you have langchain-core 1.0.0 which is incompatible.
# ...

# %%
# Split your data and create embeddings
from langchain_community.document_loaders import PyPDFDirectoryLoader
pdf_dir = "pdfs"
loader = PyPDFDirectoryLoader(pdf_dir)
data = loader.load()

from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=20)
text_chunks = text_splitter.split_documents(data)

# Fix: Use the correct import for HuggingFaceEmbeddings
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

print(f"✅ Created {len(text_chunks)} text chunks")
print(f"✅ Embedding dimension: {len(embeddings.embed_query('test'))}")
# Out:
# ✅ Created 90 text chunks
# ✅ Embedding dimension: 384

# %%
# !pip install -U langchain-pinecone
# Out:
# ...
#   Using cached langchain_core-0.3.79-py3-none-any.whl.metadata (3.2 kB)
# ...
# Using cached langchain_core-0.3.79-py3-none-any.whl (449 kB)
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.0.0
#     Uninstalling langchain-core-1.0.0:
#       Successfully uninstalled langchain-core-1.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-community 0.4 requires langchain-core<2.0.0,>=1.0.0, but you have langchain-core 0.3.79 which is incompatible.
# langchain 1.0.0 requires langchain-core<2.0.0,>=1.0.0, but you have langchain-core 0.3.79 which is incompatible.
# langchain-huggingface 1.0.0 requires langchain-core<2.0.0,>=1.0.0, but you have langchain-core 0.3.79 which is incompatible.
# langchain-classic 1.0.0 requires langchain-core<2.0.0,>=1.0.0, but you have langchain-core 0.3.79 which is incompatible.
# ...

# %%
from langchain_community.vectorstores import Pinecone
from langchain_pinecone import PineconeVectorStore
import os
from google.colab import userdata

PINECONE_API_KEY = userdata.get('PINECONE_API_KEY')
# Set the API key as an environment variable
os.environ["PINECONE_API_KEY"] = PINECONE_API_KEY

docsearch = PineconeVectorStore.from_existing_index(
    index_name=index_name,
    embedding=embeddings
)
# Out:
# /usr/local/lib/python3.12/dist-packages/langchain_pinecone/__init__.py:3: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   from langchain_pinecone.vectorstores import Pinecone, PineconeVectorStore
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2701135885.py in <cell line: 0>()
#       9
#      10 docsearch = PineconeVectorStore.from_existing_index(
# ...

# %%
docsearch
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-812739064.py in <cell line: 0>()
# ----> 1 docsearch
#
# NameError: name 'docsearch' is not defined

# %%
docsearch.as_retriever()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1936153994.py in <cell line: 0>()
# ----> 1 docsearch.as_retriever()
#
# NameError: name 'docsearch' is not defined

# %%
query="YOLOv7 outperforms which models"

# %%
docs=docsearch.similarity_search(query)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3366523841.py in <cell line: 0>()
# ----> 1 docs=docsearch.similarity_search(query)
#
# NameError: name 'docsearch' is not defined

# %%
docs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-775672773.py in <cell line: 0>()
# ----> 1 docs
#
# NameError: name 'docs' is not defined

# %%
#llm=ChatGroq()

# %%
qa=RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=docsearch.as_retriever())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1817559460.py in <cell line: 0>()
# ----> 1 qa=RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=docsearch.as_retriever())
#
# NameError: name 'RetrievalQA' is not defined

# %%
qa.run(query)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2828950282.py in <cell line: 0>()
# ----> 1 qa.run(query)
#
# NameError: name 'qa' is not defined
